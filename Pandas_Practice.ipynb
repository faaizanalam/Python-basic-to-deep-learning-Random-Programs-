# %%
import pandas as pd
import numpy as np

# %%
data = {"Saim" : [10,40,50,60,50],
        "Salam" :  [30,50,60,20,54]
    }
data
# Out:
# {'Saim': [10, 40, 50, 60, 50], 'Salam': [30, 50, 60, 20, 54]}

# %%
dt = pd.DataFrame(data)
dt
# Out:
#    Saim  Salam
# 0    10     30
# 1    40     50
# 2    50     60
# 3    60     20
# 4    50     54

# %%
print(type(data))
type(dt)
# Out:
# <class 'dict'>
# pandas.core.frame.DataFrame

# %%
data_csv = pd.read_csv('titanic.csv',index_col='PassengerId') # if index_co = 0, data will be shown without indexes
data_csv
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_csv.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data_csv.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(data_csv.shape) # prints structure of the data -- i.e : Rows and Columns
data_csv.ndim    #prints the dimensions of the data
# Out:
# (891, 11)
# 2

# %%
data_csv.describe() # Output different details of all numeric columns in a data
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data_csv.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(type(data_csv)) #---Panda DataFrame
type(data_csv['Age'])   # Panda series
# Out:
# <class 'pandas.core.frame.DataFrame'>
# pandas.core.series.Series

# %%
data_csv.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
data_csv.sort_index(axis = 0, ascending= False)
# Out:
#              Survived  Pclass  \
# PassengerId
# 891                 0       3
# 890                 1       1
# 889                 0       3
# 888                 1       1
# 887                 0       2
# ...               ...     ...
# 5                   0       3
# 4                   1       1
# 3                   1       3
# 2                   1       1
# 1                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 891                                        Dooley, Mr. Patrick    male  32.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# ...                                                        ...     ...   ...
# ...

# %%
data_csv2 = data_csv #This won't create a new DataFrame rather data_csv2 will
# act as a view of data_csv, same as a pointer pointing to a memory locatioin 
#print(data_csv2)
data_csv2.loc[1, 'Age'] = 26
data_csv
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  26.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# To create a new DataFrame, the copy() method can be used
data_csv3 = pd.DataFrame(data_csv.copy())

# %%
data_csv3
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  26.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_csv.loc[[1,40],['Name','Survived']]
# Out:
#                                     Name  Survived
# PassengerId
# 1                Braund, Mr. Owen Harris         0
# 40           Nicola-Yarred, Miss. Jamila         1

# %%
data_csv.loc[(data_csv['Age']>70)]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 852                 0       3                   Svensson, Mr. Johan  male
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 97           71.0      0      0  PC 17754  34.6542    A5        C
# 117          70.5      0      0    370369   7.7500   NaN        Q
# 494          71.0      0      0  PC 17609  49.5042   NaN        C
# 631          80.0      0      0     27042  30.0000   A23        S
# 852          74.0      0      0    347060   7.7750   NaN        S

# %%
data_csv.loc[[2,4],['Pclass','Fare','Name']]
# Out:
#              Pclass     Fare  \
# PassengerId
# 2                 1  71.2833
# 4                 1  53.1000
#
#                                                           Name
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
print(data_csv["Age"].min())
print(data_csv["Age"].max())
print(data_csv["Age"].mean())
print(data_csv['Age'].std())
# Out:
# 0.42
# 80.0
# 29.70471988795518
# 14.52429509815004

# %%
data_csv.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.704720    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.524295    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data_csv_dup = pd.concat([data_csv, data_csv])
data_csv_dup.duplicated()
data_csv_dup
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  26.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_csv_dup.drop_duplicates()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  26.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_csv.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
data_csv.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data_csv.dropna()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Data Visulalization using Pandas

# %%
data = {'Year': [2010, 2011, 2012, 2013, 2014],
        'Sales': [100, 120, 150, 200, 180]}
dt = pd.DataFrame(data)
dt
dt.plot(x='Year',y='Sales',title = 'Sales over time')
# Out:
# <Axes: title={'center': 'Sales over time'}, xlabel='Year'>

# %%
# Create a DataFrame
data = {'City': ['New York', 'Los Angeles', 'Chicago', 'Houston'],
        'Population': [8398748, 3980408, 2716000, 2326006]}
dt = pd.DataFrame(data)
dt.plot(x = 'City', y= 'Population', kind ='bar', title = 'Population by City')
# Out:
# <Axes: title={'center': 'Population by City'}, xlabel='City'>
